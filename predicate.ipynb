# %%
import spacy

nlp = spacy.load("en_core_web_sm")

sentence = "Ram gave Sita a book"

doc = nlp(sentence)

for token in doc:s
    if token.pos_ == "VERB":
        print("Predicate:", token.text)
        for child in token.children:
            if child.dep_ in ("nsubj", "dobj", "iobj"):
                print(child.dep_, ":", child.text)
# Out:
# Predicate: gave
# nsubj : Ram
# dobj : book

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (0.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (70.1.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from spacy) (24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.0)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.27.0)
# Requirement already satisfied: anyio in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.4.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.5)
# Requirement already satisfied: sniffio in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\sathe\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->spacy) (2.1.5)
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m spacy download en_core_web_sm
