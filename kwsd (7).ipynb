# %%
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize

def lesk(sentence, word):
    context = set(word_tokenize(sentence))
    best_sense = None
    max_overlap = 0

    for sense in wn.synsets(word):
        gloss = set(word_tokenize(sense.definition()))
        overlap = len(context & gloss)

        if overlap > max_overlap:
            max_overlap = overlap
            best_sense = sense

    return best_sense

# Input
sentence = input("Enter sentence: ")
word = input("Enter ambiguous word: ")

sense = lesk(sentence, word)

print("\nBest Sense:", sense)
print("Meaning:", sense.definition())
# Out:
# Enter sentence:  Sathish is a boy. Boy is gender.
# Enter ambiguous word:  boy
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - 'C:\\Users\\sathe/nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 23
#      20 sentence = input("Enter sentence: ")
#      21 word = input("Enter ambiguous word: ")
# ---> 23 sense = lesk(sentence, word)
#      25 print("\nBest Sense:", sense)
#      26 print("Meaning:", sense.definition())
#
# Cell In[1], line 9, in lesk(sentence, word)
#       6 best_sense = None
#       7 max_overlap = 0
# ----> 9 for sense in wn.synsets(word):
#      10     gloss = set(word_tokenize(sense.definition()))
#      11     overlap = len(context & gloss)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\corpus\util.py:120, in LazyCorpusLoader.__getattr__(self, attr)
#     117 if attr == "__bases__":
#     118     raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
# --> 120 self.__load()
#     121 # This looks circular, but its not, since __load() changes our
#     122 # __class__ to something new:
#     123 return getattr(self, attr)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\corpus\util.py:86, in LazyCorpusLoader.__load(self)
#      84             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85         except LookupError:
# ---> 86             raise e
#      88 # Load the corpus.
#      89 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\corpus\util.py:81, in LazyCorpusLoader.__load(self)
#      79 else:
#      80     try:
# ---> 81         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82     except LookupError as e:
#      83         try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     577 sep = "*" * 70
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - 'C:\\Users\\sathe/nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Local\\Programs\\Python\\Python312\\nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Local\\Programs\\Python\\Python312\\share\\nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Local\\Programs\\Python\\Python312\\lib\\nltk_data'
#     - 'C:\\Users\\sathe\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
